# %%
#INTERPOLATE()
import pandas as pd

# %%
df=pd.read_csv("/home/sudip/Tutorial/python /Data cleaning/student_marks.csv")

# %%
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55        NaN       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
# df = df.rename(columns={'Unnamed :0': 'Name'})

# %%
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55        NaN       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df.interpolate()#fill miss values by avarage of after before value
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55       72.5       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df.interpolate(method='linear')#same as above
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55       72.5       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
#df.interpolate(method="time")

# %%
df.interpolate(method='index')
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55       72.5       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %% [markdown]
# # pandas loc and iloc

# %%
df.loc[0]
# Out:
# Unnamed: 0          John
# Gender                 M
# DOB           05/04/1988
# Maths                 55
# Physics               45
# Chemistry             56
# English               87
# Biology               21
# Economics             52
# History               89
# Civics                65
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Unnamed: 0      Suresh
# Gender               M
# DOB           4/5/1987
# Maths               75
# Physics             55
# Chemistry          NaN
# English             64
# Biology             90
# Economics           61
# History             58
# Civics               2
# Name: 1, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55        NaN       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74

# %%
df.loc[1,'English']
# Out:
# 64

# %%
df.loc[0:3,"Maths"]
# Out:
# 0    55
# 1    75
# 2    25
# 3    78
# Name: Maths, dtype: int64

# %%
df.loc[[False,False,True,False,True]]
# Out:
#   Unnamed: 0 Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 2     Ramesh      M  25/5/1989     25       54       89.0       76       95
# 4   Jennifer      F   2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 2         87       56      74
# 4         77       83      53

# %%
df.loc[df["Maths"]>60,["Physics"]]
# Out:
#    Physics
# 1       55
# 3       55

# %%
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
# 1     Suresh      M    4/5/1987     75       55        NaN       64       90
# 2     Ramesh      M   25/5/1989     25       54       89.0       76       95
# 3    Jessica      F   12/8/1990     78       55       86.0       63       54
# 4   Jennifer      F    2/9/1989     58       96       78.0       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %% [markdown]
# # ILOC (integer based location indexing)

# %%
df.iloc[[0]]
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05/04/1988     55       45       56.0       87       21
#
#    Economics  History  Civics
# 0         52       89      65

# %%
df.iloc[:,0]
# Out:
# 0        John
# 1      Suresh
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# Name: Unnamed: 0, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'M'

# %%
df.iloc[[False,False,True,True,False]]
# Out:
#   Unnamed: 0 Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 2     Ramesh      M  25/5/1989     25       54       89.0       76       95
# 3    Jessica      F  12/8/1990     78       55       86.0       63       54
#
#    Economics  History  Civics
# 2         87       56      74
# 3         89       75      45
