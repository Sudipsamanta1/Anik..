# %%
import pandas as pd

# %%
abc_data=pd.DataFrame()
print(abc_data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Lst=['a','b','c']
df1=pd.DataFrame(Lst)
print(Lst)
# Out:
# ['a', 'b', 'c']

# %%
# comma separed value handling

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv")

# %%
import os

# %%
print(os.getcwd())
# Out:
# /home/sudip/Tutorial/python /PANDAS

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12           5
# 5        Vijay Rupani            2              4       6          32
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12       45     76     34
# 1           23       56      8     12
# 2           54        7      8      9
# 3           32       56     12     56
# 4          112       45     23     67
# 5           43      101      2     35
# 6           12        0     98      2
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",nrows=1)

# %%
df
# Out:
#         name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0  Mamata Banerjee           80             29      46           9
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12       45     76     34

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",usecols=[0,5])

# %%
df
# Out:
#            name/state  Maharashtra
# 0     Mamata Banerjee           12
# 1     Yogi Adityanath           23
# 2    Prem ingh Tamang           54
# 3     V. Narayanasamy           32
# 4    Uddhav Thackeray          112
# 5        Vijay Rupani           43
# 6  Sarbananda Sonowal           12
# 7     Arvind Kejriwal           34

# %%
df1=df=pd.read_csv("/home/sudip/Desktop/dataset.csv",skiprows=1)

# %%
df1
# Out:
#       Mamata Banerjee  80  29  46   9   12   45  76   34
# 0     Yogi Adityanath  12  98  43  67   23   56   8   12
# 1    Prem ingh Tamang   2   5  67  23   54    7   8    9
# 2     V. Narayanasamy   4  32  21  90   32   56  12   56
# 3    Uddhav Thackeray  32  54  12   5  112   45  23   67
# 4        Vijay Rupani   2   4   6  32   43  101   2   35
# 5  Sarbananda Sonowal  32   3  45   2   12    0  98    2
# 6     Arvind Kejriwal  45  21  34  26   34   54  10  124

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",index_col='name/state')

# %%
df
# Out:
#                     West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# name/state
# Mamata Banerjee              80             29      46           9
# Yogi Adityanath              12             98      43          67
# Prem ingh Tamang              2              5      67          23
# V. Narayanasamy               4             32      21          90
# Uddhav Thackeray             32             54      12           5
# Vijay Rupani                  2              4       6          32
# Sarbananda Sonowal           32              3      45           2
# Arvind Kejriwal              45             21      34          26
#
#                     Maharashtra  Gujarat  Assam  Delhi
# name/state
# Mamata Banerjee              12       45     76     34
# Yogi Adityanath              23       56      8     12
# Prem ingh Tamang             54        7      8      9
# V. Narayanasamy              32       56     12     56
# Uddhav Thackeray            112       45     23     67
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",header=1)

# %%
df
# Out:
#       Mamata Banerjee  80  29  46   9   12   45  76   34
# 0     Yogi Adityanath  12  98  43  67   23   56   8   12
# 1    Prem ingh Tamang   2   5  67  23   54    7   8    9
# 2     V. Narayanasamy   4  32  21  90   32   56  12   56
# 3    Uddhav Thackeray  32  54  12   5  112   45  23   67
# 4        Vijay Rupani   2   4   6  32   43  101   2   35
# 5  Sarbananda Sonowal  32   3  45   2   12    0  98    2
# 6     Arvind Kejriwal  45  21  34  26   34   54  10  124

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",index_col='name/state')

# %%
df
# Out:
#                     West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# name/state
# Mamata Banerjee              80             29      46           9
# Yogi Adityanath              12             98      43          67
# Prem ingh Tamang              2              5      67          23
# V. Narayanasamy               4             32      21          90
# Uddhav Thackeray             32             54      12           5
# Vijay Rupani                  2              4       6          32
# Sarbananda Sonowal           32              3      45           2
# Arvind Kejriwal              45             21      34          26
#
#                     Maharashtra  Gujarat  Assam  Delhi
# name/state
# Mamata Banerjee              12       45     76     34
# Yogi Adityanath              23       56      8     12
# Prem ingh Tamang             54        7      8      9
# V. Narayanasamy              32       56     12     56
# Uddhav Thackeray            112       45     23     67
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",header=None)

# %%
df
# Out:
#                     0            1              2       3           4  \
# 0          name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry
# 1     Mamata Banerjee           80             29      46           9
# 2     Yogi Adityanath           12             98      43          67
# 3    Prem ingh Tamang            2              5      67          23
# 4     V. Narayanasamy            4             32      21          90
# 5    Uddhav Thackeray           32             54      12           5
# 6        Vijay Rupani            2              4       6          32
# 7  Sarbananda Sonowal           32              3      45           2
# 8     Arvind Kejriwal           45             21      34          26
#
#              5        6      7      8
# 0  Maharashtra  Gujarat  Assam  Delhi
# 1           12       45     76     34
# 2           23       56      8     12
# 3           54        7      8      9
# 4           32       56     12     56
# ...

# %%
#prefix
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",header=None,prefix='column')

# %%
df
# Out:
#               column0      column1        column2 column3     column4  \
# 0          name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry
# 1     Mamata Banerjee           80             29      46           9
# 2     Yogi Adityanath           12             98      43          67
# 3    Prem ingh Tamang            2              5      67          23
# 4     V. Narayanasamy            4             32      21          90
# 5    Uddhav Thackeray           32             54      12           5
# 6        Vijay Rupani            2              4       6          32
# 7  Sarbananda Sonowal           32              3      45           2
# 8     Arvind Kejriwal           45             21      34          26
#
#        column5  column6 column7 column8
# 0  Maharashtra  Gujarat   Assam   Delhi
# 1           12       45      76      34
# 2           23       56       8      12
# 3           54        7       8       9
# 4           32       56      12      56
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",names=['a','b','c','d','e','f','g','h','i','j'])

# %%
df
# Out:
#                     a            b              c       d           e  \
# 0          name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry
# 1     Mamata Banerjee           80             29      46           9
# 2     Yogi Adityanath           12             98      43          67
# 3    Prem ingh Tamang            2              5      67          23
# 4     V. Narayanasamy            4             32      21          90
# 5    Uddhav Thackeray           32             54      12           5
# 6        Vijay Rupani            2              4       6          32
# 7  Sarbananda Sonowal           32              3      45           2
# 8     Arvind Kejriwal           45             21      34          26
#
#              f        g      h      i   j
# 0  Maharashtra  Gujarat  Assam  Delhi NaN
# 1           12       45     76     34 NaN
# 2           23       56      8     12 NaN
# 3           54        7      8      9 NaN
# 4           32       56     12     56 NaN
# ...

# %%
df.head(4)
# Out:
#                   a            b              c       d           e  \
# 0        name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry
# 1   Mamata Banerjee           80             29      46           9
# 2   Yogi Adityanath           12             98      43          67
# 3  Prem ingh Tamang            2              5      67          23
#
#              f        g      h      i   j
# 0  Maharashtra  Gujarat  Assam  Delhi NaN
# 1           12       45     76     34 NaN
# 2           23       56      8     12 NaN
# 3           54        7      8      9 NaN

# %%
df.tail(5)
# Out:
#                     a   b   c   d   e    f    g   h    i   j
# 4     V. Narayanasamy   4  32  21  90   32   56  12   56 NaN
# 5    Uddhav Thackeray  32  54  12   5  112   45  23   67 NaN
# 6        Vijay Rupani   2   4   6  32   43  101   2   35 NaN
# 7  Sarbananda Sonowal  32   3  45   2   12    0  98    2 NaN
# 8     Arvind Kejriwal  45  21  34  26   34   54  10  124 NaN

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",dtype={'Gujarat':'float64'})

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12           5
# 5        Vijay Rupani            2              4       6          32
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12     45.0     76     34
# 1           23     56.0      8     12
# 2           54      7.0      8      9
# 3           32     56.0     12     56
# 4          112     45.0     23     67
# 5           43    101.0      2     35
# 6           12      0.0     98      2
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",true_values=['yes'])#change level as true

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12           5
# 5        Vijay Rupani            2              4       6          32
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12       45     76     34
# 1           23       56      8     12
# 2           54        7      8      9
# 3           32       56     12     56
# 4          112       45     23     67
# 5           43      101      2     35
# 6           12        0     98      2
# ...

# %% [markdown]
# # handling missing values in python

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv")

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12         112
# 5        Vijay Rupani            2              4      32          43
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12       45     76   34.0
# 1           23       56      8   12.0
# 2            7        8      9    NaN
# 3           32       56     12   56.0
# 4           45       23     67    NaN
# 5          101        2     35    NaN
# 6           12       98      2    NaN
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",na_values='no values')

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12         112
# 5        Vijay Rupani            2              4      32          43
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam  Delhi
# 0           12       45     76   34.0
# 1           23       56      8   12.0
# 2            7        8      9    NaN
# 3           32       56     12   56.0
# 4           45       23     67    NaN
# 5          101        2     35    NaN
# 6           12       98      2    NaN
# ...

# %%
df=pd.read_csv("/home/sudip/Desktop/dataset.csv",na_filter=False,'no values')

# %%
df
# Out:
#            name/state  West Bengal  Uttar Pradesh  Sikkim  Puducherry  \
# 0     Mamata Banerjee           80             29      46           9
# 1     Yogi Adityanath           12             98      43          67
# 2    Prem ingh Tamang            2              5      67          23
# 3     V. Narayanasamy            4             32      21          90
# 4    Uddhav Thackeray           32             54      12         112
# 5        Vijay Rupani            2              4      32          43
# 6  Sarbananda Sonowal           32              3      45           2
# 7     Arvind Kejriwal           45             21      34          26
#
#    Maharashtra  Gujarat  Assam Delhi
# 0           12       45     76    34
# 1           23       56      8    12
# 2            7        8      9
# 3           32       56     12    56
# 4           45       23     67
# 5          101        2     35
# 6           12       98      2
# 7           34       54    124
