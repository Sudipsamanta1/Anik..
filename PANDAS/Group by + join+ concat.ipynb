# %% [markdown]
# #  group by

# %%
import pandas as pd

# %%
df=pd.read_csv("/home/sudip/Tutorial/python /Data cleaning/main_data.csv")

# %%
df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6005    Joseph Kosinski       Tom Cruise      Miles Teller
# 6006      Joel Crawford     Nicolas Cage        Emma Stone
# 6007        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6008       Ridley Scott       Matt Damon       Adam Driver
# 6009    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
df2=df.head(50)

# %%
gr1=df2.groupby(by="genres")

# %%
gr1

# %%
gr1.groups
# Out:
# {'Action Adventure': [11], 'Action Adventure Comedy Family Fantasy Sci-Fi': [17], 'Action Adventure Drama History': [20], 'Action Adventure Family Fantasy': [15], 'Action Adventure Fantasy': [1, 12, 16, 19, 46], 'Action Adventure Fantasy Romance': [27, 43], 'Action Adventure Fantasy Sci-Fi': [0, 14, 33], 'Action Adventure Fantasy Sci-Fi Thriller': [29, 40], 'Action Adventure Horror Sci-Fi Thriller': [39], 'Action Adventure Sci-Fi': [5, 7, 9, 10, 24, 28, 31, 32, 35, 37, 41, 44, 45], 'Action Adventure Sci-Fi Thriller': [25, 26, 49], 'Action Adventure Thriller': [2], 'Action Adventure Western': [13], 'Action Crime Thriller': [38], 'Action Thriller': [3], 'Adventure Animation Comedy Family Fantasy': [30, 36, 47, 48], 'Adventure Animation Comedy Family Fantasy Musical Romance': [6], 'Adventure Animation Comedy Family Sport': [34], 'Adventure Family Fantasy': [22], 'Adventure Family Fantasy Mystery': [8], 'Adventure Fantasy': [18, 21, 42], 'Documentary': [4], 'Drama Romance': [23]}

# %%
df.groupby(["actor_1_name","genres"]).groups
# Out:
# {('50 Cent', 'Biography Crime Drama Music'): [1213], ('A. J. Bowen', 'Horror'): [5699], ('A.J. Buckley', 'Adventure Animation Comedy Family Fantasy'): [47], ('Aaliyah', 'Drama Fantasy Horror'): [1389], ('Aaron Paul', 'Crime Drama Thriller Action'): [5810], ('Aaron Taylor-Johnson', 'Drama'): [5850], ('Aaron Taylor-Johnson', 'Drama Thriller War'): [5140], ('Aasif Mandvi', 'Comedy Drama Fantasy Romance'): [2183], ('Abbi Jacobson', 'Animation Adventure Comedy Family Science Fiction'): [5987], ('Abbie Cornish', 'Action Adventure Animation Family Fantasy'): [282], ('Abbie Cornish', 'Biography Drama Romance'): [3217], ('Abbie Cornish', 'Comedy Crime'): [2711], ('Abbie Cornish', 'Drama Thriller'): [4994], ('Abhishek Bachchan', 'Action Crime Drama Thriller'): [3567], ('Abhishek Bachchan', 'Comedy Musical Romance'): [4336], ('Abigail Breslin', 'Music Drama Romance TV Movie'): [5320], ('Abigail Evans', 'Documentary'): [4789], ('Abigail Spencer', 'Drama Horror Mystery Thriller'): [3215], ('Adam 
# ...

# %%
for genres,df1 in gr1:
    print(genres)
    print(df1)
# Out:
# Action Adventure
#    director_name        actor_1_name     actor_2_name  actor_3_name  \
# 11  Marc Forster  Giancarlo Giannini  Mathieu Amalric  Rory Kinnear
#
#               genres        movie_title  \
# 11  Action Adventure  quantum of solace
#
#                                                  comb
# 11  Giancarlo Giannini Mathieu Amalric Rory Kinnea...
# Action Adventure Comedy Family Fantasy Sci-Fi
#        director_name actor_1_name       actor_2_name        actor_3_name  \
# 17  Barry Sonnenfeld   Will Smith  Michael Stuhlbarg  Nicole Scherzinger
#
#                                            genres     movie_title  \
# 17  Action Adventure Comedy Family Fantasy Sci-Fi  men in black 3
#
#                                                  comb
# 17  Will Smith Michael Stuhlbarg Nicole Scherzinge...
# Action Adventure Drama History
#    director_name actor_1_name  actor_2_name  actor_3_name  \
# 20  Ridley Scott    Mark Addy  William Hurt  Scott Grimes
#
# ...

# %%
list(gr1)
# Out:
# [('Action Adventure',
#      director_name        actor_1_name     actor_2_name  actor_3_name  \
#   11  Marc Forster  Giancarlo Giannini  Mathieu Amalric  Rory Kinnear
#
#                 genres        movie_title  \
#   11  Action Adventure  quantum of solace
#
#                                                    comb
#   11  Giancarlo Giannini Mathieu Amalric Rory Kinnea...  ),
#  ('Action Adventure Comedy Family Fantasy Sci-Fi',
#          director_name actor_1_name       actor_2_name        actor_3_name  \
#   17  Barry Sonnenfeld   Will Smith  Michael Stuhlbarg  Nicole Scherzinger
#
#                                              genres     movie_title  \
#   17  Action Adventure Comedy Family Fantasy Sci-Fi  men in black 3
#
#                                                    comb
#   17  Will Smith Michael Stuhlbarg Nicole Scherzinge...  ),
#  ('Action Adventure Drama History',
#      director_name actor_1_name  actor_2_name  actor_3_name  \
# ...

# %%
dict(list(gr1))
# Out:
# {'Action Adventure':    director_name        actor_1_name     actor_2_name  actor_3_name  \
#  11  Marc Forster  Giancarlo Giannini  Mathieu Amalric  Rory Kinnear
#
#                genres        movie_title  \
#  11  Action Adventure  quantum of solace
#
#                                                   comb
#  11  Giancarlo Giannini Mathieu Amalric Rory Kinnea...  ,
#  'Action Adventure Comedy Family Fantasy Sci-Fi':        director_name actor_1_name       actor_2_name        actor_3_name  \
#  17  Barry Sonnenfeld   Will Smith  Michael Stuhlbarg  Nicole Scherzinger
#
#                                             genres     movie_title  \
#  17  Action Adventure Comedy Family Fantasy Sci-Fi  men in black 3
#
#                                                   comb
#  17  Will Smith Michael Stuhlbarg Nicole Scherzinge...  ,
#  'Action Adventure Drama History':    director_name actor_1_name  actor_2_name  actor_3_name  \
#  20  Ridley Scott    Mark Addy  William Hurt  Scott Grimes
# ...
